# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
img1=mpimg.imread('C:/Users/Pierre Lavigne/Dropbox/Etude de Cas M2/lowpixel.jpg')
img2=mpimg.imread('C:/Users/Pierre Lavigne/Dropbox/Etude de Cas M2/lowpixel_modif.jpg')
plt.imshow(img1)
plt.show()
plt.imshow(img2)
plt.show()

# %%
np.dot(img2[100][0],img1[0][0])/np.dot(img1[0][0],img1[0][0])
# Out:
# 0.13821138

# %% [markdown]
# ### According to the paper 'on the euclidean distance of images' we build the matrix of cosinus (le plus 1 évite la division par zero):

# %%
imag1 = img1.reshape(1,img1.shape[1]*img1.shape[0],3)[0]
imag2 = img2.reshape(1,img2.shape[1]*img2.shape[0],3)[0]
imag1[2]
# Out:
# array([204, 204, 204], dtype=uint8)

# %%
def cosmat(imag1,imag2):
    mn = range(imag1.shape[0])
    matrix = [[0 for i in mn] for j in mn]
    for (i,j) in zip(mn,mn):
        print(i,j)
        matrix[i][j] = np.dot(imag1[i],imag2[j])/(norm(imag1[i])*norm(imag2[j])+1)
    return matrix

# %%
cosmat(imag1,imag2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8d870945e69e> in <module>()
# ----> 1 cosmat(imag1,imag2)
#
# <ipython-input-4-8f85c55fcbfd> in cosmat(imag1, imag2)
#       1 def cosmat(imag1,imag2):
#       2     mn = range(imag1.shape[0])
# ----> 3     matrix = [[0 for i in mn] for j in mn]
#       4     for (i,j) in zip(mn,mn):
#       5         print(i,j)
#
# <ipython-input-4-8f85c55fcbfd> in <listcomp>(.0)
#       1 def cosmat(imag1,imag2):
#       2     mn = range(imag1.shape[0])
# ----> 3     matrix = [[0 for i in mn] for j in mn]
#       4     for (i,j) in zip(mn,mn):
#       5         print(i,j)
#
# <ipython-input-4-8f85c55fcbfd> in <listcomp>(.0)
#       1 def cosmat(imag1,imag2):
#       2     mn = range(imag1.shape[0])
# ----> 3     matrix = [[0 for i in mn] for j in mn]
#       4     for (i,j) in zip(mn,mn):
#       5         print(i,j)
#
# ...

# %%
def transform(im):
    
    for i in range(im.shape[0]):
        for j in range(im.shape[1]):
# Out:
# 29.444863728670914

# %%
import cv2 as cv
small = cv.resize(img, (0,0), fx=0.5, fy=0.5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-8860bcb4189d> in <module>()
# ----> 1 import cv2 as cv
#       2 small = cv.resize(img, (0,0), fx=0.5, fy=0.5)
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ## plot de la distribution des pixels
#
# http://pot.readthedocs.io/en/stable/auto_examples/plot_otda_mapping_colors_images.html

# %%
# Authors: Remi Flamary <remi.flamary@unice.fr>
#          Stanislas Chambon <stan.chambon@gmail.com>
#
# License: MIT License

import numpy as np
from scipy import ndimage
import matplotlib.pylab as pl

r = np.random.RandomState(42)


def im2mat(I):
    """Converts and image to matrix (one pixel per line)"""
    return I.reshape((I.shape[0] * I.shape[1], I.shape[2]))

# %%
X1 = im2mat(img1)
X2 = im2mat(img2)

# training samples
nb = 1000
idx1 = r.randint(X1.shape[0], size=(nb,))
idx2 = r.randint(X2.shape[0], size=(nb,))

Xs = X1[idx1, :]
Xt = X2[idx2, :]

# %%
plt.scatter(Xs[:, 0]/255, Xs[:, 1]/255, c=X)
plt.show()
plt.scatter(Xt[:, 0]/255, Xt[:, 1]/255, c=X)
plt.show()

# %%
plt.scatter(Xs[:, 0]/255, Xs[:, 2]/255, c=X)
plt.show()
plt.scatter(Xt[:, 0]/255, Xt[:, 2]/255, c=X)
plt.show()
